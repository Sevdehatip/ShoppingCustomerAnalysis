# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-785cff5c-c267-4356-acd2-51b7c21e5fc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-785cff5c-c267-4356-acd2-51b7c21e5fc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Shopping_CustomerData.csv to Shopping_CustomerData.csv

# %%
df= pd.read_csv("./Shopping_CustomerData.csv")

# %%
df.head()
# Out:
#    CustomerID CustomerGender  ...  SpendingScore CustomerCityID
# 0        1001           Male  ...             78              1
# 1        1002           Male  ...             63              1
# 2        1003         Female  ...             69              4
# 3        1004         Female  ...             30              1
# 4        1005         Female  ...              6              1
#
# [5 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      200 non-null    int64
#  1   CustomerGender  200 non-null    object
#  2   CustomerAge     200 non-null    int64
#  3   CustomerCity    200 non-null    object
#  4   AnnualIncome    200 non-null    float64
#  5   CreditScore     200 non-null    int64
#  6   SpendingScore   200 non-null    int64
#  7   CustomerCityID  200 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 12.6+ KB

# %%
df.describe()
# Out:
#         CustomerID  CustomerAge  ...  SpendingScore  CustomerCityID
# count   200.000000   200.000000  ...      200.00000      200.000000
# mean   1100.500000    45.520000  ...       50.70500        2.850000
# std      57.879185    16.113592  ...       28.72269        1.475938
# min    1001.000000    18.000000  ...        2.00000        1.000000
# 25%    1050.750000    31.750000  ...       27.75000        1.750000
# 50%    1100.500000    46.500000  ...       48.00000        3.000000
# 75%    1150.250000    59.000000  ...       77.00000        4.000000
# max    1200.000000    75.000000  ...      100.00000        5.000000
#
# [8 rows x 6 columns]

# %%
df.isna()
# Out:
#      CustomerID  CustomerGender  ...  SpendingScore  CustomerCityID
# 0         False           False  ...          False           False
# 1         False           False  ...          False           False
# 2         False           False  ...          False           False
# 3         False           False  ...          False           False
# 4         False           False  ...          False           False
# ..          ...             ...  ...            ...             ...
# 195       False           False  ...          False           False
# 196       False           False  ...          False           False
# 197       False           False  ...          False           False
# 198       False           False  ...          False           False
# 199       False           False  ...          False           False
#
# [200 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# CustomerID        0
# CustomerGender    0
# CustomerAge       0
# CustomerCity      0
# AnnualIncome      0
# CreditScore       0
# SpendingScore     0
# CustomerCityID    0
# dtype: int64

# %% [markdown]
# dropna ile silme yapılabilir.
#
#
# datax=df.dropna() datax e kaydetmiş olur.
#
#
# data.dropna(inplace=true) na verileri atıp kendine eşitlemiş oluyor.
#
# data.dropna(axis=1) 1 ise kolondan temizleme, 0 ise satırdan temizleme
#
# data["CustomerGender"] - type: pandas serisi
#
# data[["CustomerGender"]] - type: dataframe şeklinde olur

# %%
df["CustomerCity"].value_counts()
# Out:
# Bengaluru    50
# Chennai      45
# Mumbai       39
# Delhi        37
# Kolkata      29
# Name: CustomerCity, dtype: int64

# %%
df["CustomerCity"]=="Mumbai"  ##aralarda Mumbai olan yerler true olarak geliyor
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Name: CustomerCity, Length: 200, dtype: bool

# %%
df[df["CustomerCity"]=="Mumbai"] ##sadece mumbai olan veriler geldi
# Out:
#      CustomerID CustomerGender  ...  SpendingScore CustomerCityID
# 7          1008         Female  ...             77              5
# 13         1014         Female  ...             29              5
# 17         1018           Male  ...             49              5
# 18         1019           Male  ...             75              5
# 23         1024           Male  ...             64              5
# 36         1037         Female  ...             93              5
# 37         1038         Female  ...             77              5
# 38         1039         Female  ...             97              5
# 39         1040         Female  ...             78              5
# 40         1041         Female  ...              4              5
# 47         1048         Female  ...             46              5
# 53         1054           Male  ...             36              5
# 58         1059         Female  ...             25              5
# ...

# %%
df[(df["CustomerCity"]=="Mumbai") | (df["CustomerCity"]=="Delhi")] ## Mumbai veya Delhi olanlar geldi ama 've (&)' operatörü olmaz. Aynı kolonda ve olmaz. Mumbai ve Female olur.
# Out:
#      CustomerID CustomerGender  ...  SpendingScore CustomerCityID
# 2          1003         Female  ...             69              4
# 7          1008         Female  ...             77              5
# 12         1013         Female  ...             64              4
# 13         1014         Female  ...             29              5
# 17         1018           Male  ...             49              5
# ..          ...            ...  ...            ...            ...
# 189        1190         Female  ...              7              4
# 190        1191         Female  ...             96              4
# 191        1192         Female  ...             34              5
# 195        1196         Female  ...             52              4
# 198        1199           Male  ...             24              4
#
# [76 rows x 8 columns]

# %%
df_selected=df[(df["CustomerCity"]=="Mumbai") & (df["CustomerGender"]=="Female")]
df_selected
# Out:
#      CustomerID CustomerGender  ...  SpendingScore CustomerCityID
# 7          1008         Female  ...             77              5
# 13         1014         Female  ...             29              5
# 36         1037         Female  ...             93              5
# 37         1038         Female  ...             77              5
# 38         1039         Female  ...             97              5
# 39         1040         Female  ...             78              5
# 40         1041         Female  ...              4              5
# 47         1048         Female  ...             46              5
# 58         1059         Female  ...             25              5
# 66         1067         Female  ...             96              5
# 69         1070         Female  ...             70              5
# 73         1074         Female  ...             18              5
# 93         1094         Female  ...             62              5
# ...

# %%
df_selected.groupby(by="CustomerCity").agg(["min", "mean", "max"])
# Out:
#              CustomerID                     ... CustomerCityID
#                     min         mean   max  ...            min mean max
# CustomerCity                                ...
# Mumbai             1008  1092.958333  1192  ...              5    5   5
#
# [1 rows x 18 columns]

# %%
annual_avg=df_selected["AnnualIncome"]

# %%
sns.distplot(annual_avg)

# %%
df_select=df[(df["CustomerCity"]=="Mumbai") | (df["CustomerCity"]=="Delhi") | (df["CustomerCity"]=="Kolkata")]

# %%
city_select=df_select["CustomerCity"].unique()

for city in city_select:
  dfann=df_select[df_select["CustomerCity"]==city]["AnnualIncome"]
  sns.distplot(dfann)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15,5))

city_select=df_select["CustomerCity"].unique()

for city in city_select:
  dfann=df_select[df_select["CustomerCity"]==city]["AnnualIncome"]
  sns.distplot(dfann)

plt.legend(city_select)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(20,8))

cityall_select=df["CustomerCity"].unique()

for city in cityall_select:
  dfallann=df[df["CustomerCity"]==city]["AnnualIncome"]
  sns.distplot(dfallann)

plt.legend(cityall_select)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(20,8))
colors=["blue","orange", "green", "red", "purple" ]  ##renkleri de döngüye alarak hangisine ait olduğunu anlayabiliriz

cityall_select=df["CustomerCity"].unique()

for color, city in zip(colors, cityall_select):
  dfallann=df[df["CustomerCity"]==city]["AnnualIncome"]
  sns.distplot(dfallann)
  city_mean=dfallann.mean() ##ortalamaları 
  plt.vlines(city_mean, 0, 0.0000028, colors=color)  ##y 0-0.00..28 arasını

plt.legend(cityall_select)

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(x="CustomerAge", y="AnnualIncome", data=df)

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(x="CustomerAge", y="SpendingScore", data=df, hue="SpendingScore")

# %%
plt.figure(figsize=(12,3))
sns.scatterplot(x="CustomerAge", y="SpendingScore", data=df, hue="CustomerCity")

# %%
plt.figure(figsize=(20,8))

sns.lineplot(x="CustomerAge", y="SpendingScore", data=df)

# %%
data1=df[["CustomerGender", "AnnualIncome"]].groupby(['CustomerGender'], as_index=False).mean().sort_values(by='AnnualIncome', ascending=False)
sns.barplot(x='CustomerGender', y='AnnualIncome', data=data1)

# %%
data2=df[["CustomerGender", "CreditScore"]].groupby(['CustomerGender'], as_index=False).mean().sort_values(by='CreditScore', ascending=False)
sns.barplot(x="CustomerGender",y="CreditScore",data=data2)

# %%
data3=df[["CustomerGender", "SpendingScore"]].groupby(['CustomerGender'], as_index=False).mean().sort_values(by='SpendingScore', ascending=False)
sns.barplot(x="CustomerGender",y="SpendingScore",data=data3)

# %%
sns.countplot(x="CustomerGender", data=df)

# %%
data4=df[["CustomerAge", "SpendingScore"]].groupby(['CustomerAge'], as_index=False).sum().\
                sort_values(by='SpendingScore', ascending=False)
plt.figure(figsize=[16,6])
sns.barplot(x="CustomerAge",y="SpendingScore",data=data4,orient="v")

# %%
data5=df[["CustomerAge", "AnnualIncome"]].groupby(['CustomerAge'], as_index=False).sum().\
                sort_values(by='AnnualIncome', ascending=False)
plt.figure(figsize=[16,6])
sns.barplot(x="CustomerAge",y="AnnualIncome",data=data5)

# %%
data6=df[["CustomerAge", "CreditScore"]].groupby(['CustomerAge'], as_index=False).sum().\
                sort_values(by='CreditScore', ascending=False)
plt.figure(figsize=[16,6])
sns.barplot(x="CustomerAge",y="CreditScore",data=data6)

# %%
sns.pairplot(df)
plt.plot()
# Out:
# []
